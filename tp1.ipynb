# %%
import cv2
import numpy as np
# cv2.imread('filename', 'flags')
# cv2.imshow(window_name, img)import numpy as np
import matplotlib.pyplot as plt

# %%
img  = np.zeros((500, 500, 3), np.uint8) #grayscale (h,w,c), types
img[ :, :, 1] = 255

# %%
# cv2.imshow('Image 1', img)
# cv2.waitKey(0) #waits for 0 to close the image
# cv2.destroyAllWindows()
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
img  = cv2.imread('img.jpg', cv2.IMREAD_COLOR)
if img is None:
    print("erreur de chargement")
    exit(0)

# %%
img2  = np.zeros(img.shape, img.dtype)
img2 = 255 - img #all the image
img2[100:300,100:300] = 255 - img[100:300,100:300] #part of the image

# %%
img3 = img2  = np.zeros((500,500), np.uint8)


for y in range(img3.shape[0]):
    for x in range(img3.shape[1]):
        img2[y,x] = (y+x)*255/(500+500)

# %%
# cv2.imshow('image2', img2)
# cv2.imshow('image1', img)
# cv2.imshow('image3', img3)
# cv2.waitKey(0) #waits for 0 to close the image
# cv2.destroyAllWindows()
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
img_rgb2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb2)
plt.show()

# %%
img_rgb3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb3)
plt.show()
